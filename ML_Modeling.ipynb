# %%
#---------------Install the Required Libraries------------------#
# !pip install scikit-learn
# Out:
# Requirement already satisfied: scikit-learn in C:\Users\chinn\ml_workshop_env\Lib\site-packages (1.9.0)
# Requirement already satisfied: numpy>=1.24.1 in C:\Users\chinn\ml_workshop_env\Lib\site-packages (from scikit-learn) (2.4.6)
# Requirement already satisfied: scipy>=1.10.0 in C:\Users\chinn\ml_workshop_env\Lib\site-packages (from scikit-learn) (1.17.1)
# Requirement already satisfied: joblib>=1.4.0 in C:\Users\chinn\ml_workshop_env\Lib\site-packages (from scikit-learn) (1.5.3)
# Requirement already satisfied: narwhals>=2.0.1 in C:\Users\chinn\ml_workshop_env\Lib\site-packages (from scikit-learn) (2.24.0)
# Requirement already satisfied: threadpoolctl>=3.5.0 in C:\Users\chinn\ml_workshop_env\Lib\site-packages (from scikit-learn) (3.6.0)

# %%
#----------------import Libraries----------------------------------#
import numpy as np
import pandas as pd
import sklearn

# %%
#----------------Creating Data With Four Samples-------------------------#
data = pd.DataFrame({'Price_USA':[80,50,140,25],
                     'Price_INR':[5000,7000,12000,3000]})
data
# Out:
#    Price_USA  Price_INR
# 0         80       5000
# 1         50       7000
# 2        140      12000
# 3         25       3000

# %%
#-----------Performing Mathematical Wise----------------#
#created Price_USA_minmax Coloumn with original scaled values
data['Price_USA_minmax'] = (data['Price_USA']-data['Price_USA'].min())/(data['Price_USA'].max()-data['Price_USA'].min())
data
# Out:
#    Price_USA  Price_INR  Price_USA_minmax
# 0         80       5000          0.478261
# 1         50       7000          0.217391
# 2        140      12000          1.000000
# 3         25       3000          0.000000

# %%
#created Price_USA_minmax Coloumn with original scaled values using Mathematical formula
data['Price_INR_minmax'] = (data['Price_INR']-data['Price_INR'].min())/(data['Price_INR'].max()-data['Price_INR'].min())
data
# Out:
#    Price_USA  Price_INR  Price_USA_minmax  Price_INR_minmax
# 0         80       5000          0.478261          0.222222
# 1         50       7000          0.217391          0.444444
# 2        140      12000          1.000000          1.000000
# 3         25       3000          0.000000          0.000000

# %%
#created Price_USA_minsk Coloumn with original scaled values using SkLearn

from sklearn.preprocessing import MinMaxScaler,StandardScaler

# %%
min_max = MinMaxScaler()

# %%
#We Need To USe fit_transform()
data['Pice_USA_minsk'] = min_max.fit_transform(data[['Price_USA']])
data
# Out:
#    Price_USA  Price_INR  Price_USA_minmax  Price_INR_minmax  Pice_USA_minsk
# 0         80       5000          0.478261          0.222222        0.478261
# 1         50       7000          0.217391          0.444444        0.217391
# 2        140      12000          1.000000          1.000000        1.000000
# 3         25       3000          0.000000          0.000000        0.000000

# %%
data['Pice_INR_minsk'] = min_max.fit_transform(data[['Price_INR']])
data
# Out:
#    Price_USA  Price_INR  Price_USA_minmax  Price_INR_minmax  Pice_USA_minsk  \
# 0         80       5000          0.478261          0.222222        0.478261
# 1         50       7000          0.217391          0.444444        0.217391
# 2        140      12000          1.000000          1.000000        1.000000
# 3         25       3000          0.000000          0.000000        0.000000
#
#    Pice_INR_minsk
# 0        0.222222
# 1        0.444444
# 2        1.000000
# 3        0.000000

# %%
data['Price_USA_std'] = (data['Price_USA']-data['Price_USA'].mean()) / data['Price_USA'].std()
data
# Out:
#    Price_USA  Price_INR  Price_USA_minmax  Price_INR_minmax  Pice_USA_minsk  \
# 0         80       5000          0.478261          0.222222        0.478261
# 1         50       7000          0.217391          0.444444        0.217391
# 2        140      12000          1.000000          1.000000        1.000000
# 3         25       3000          0.000000          0.000000        0.000000
#
#    Pice_INR_minsk  Price_USA_std
# 0        0.222222       0.126108
# 1        0.444444      -0.479212
# 2        1.000000       1.336748
# 3        0.000000      -0.983645

# %%
data['Price_INR_std'] = (data['Price_INR']-data['Price_INR'].mean()) / data['Price_INR'].std()
data
# Out:
#    Price_USA  Price_INR  Price_USA_minmax  Price_INR_minmax  Pice_USA_minsk  \
# 0         80       5000          0.478261          0.222222        0.478261
# 1         50       7000          0.217391          0.444444        0.217391
# 2        140      12000          1.000000          1.000000        1.000000
# 3         25       3000          0.000000          0.000000        0.000000
#
#    Pice_INR_minsk  Price_USA_std  Price_INR_std
# 0        0.222222       0.126108      -0.453108
# 1        0.444444      -0.479212       0.064730
# 2        1.000000       1.336748       1.359325
# 3        0.000000      -0.983645      -0.970947

# %%
from sklearn.preprocessing import StandardScaler

# %%
scaler = StandardScaler()

# %%
data['Price_USA_scaler'] = scaler.fit_transform(data[['Price_USA']])
data
# Out:
#    Price_USA  Price_INR  Price_USA_minmax  Price_INR_minmax  Pice_USA_minsk  \
# 0         80       5000          0.478261          0.222222        0.478261
# 1         50       7000          0.217391          0.444444        0.217391
# 2        140      12000          1.000000          1.000000        1.000000
# 3         25       3000          0.000000          0.000000        0.000000
#
#    Pice_INR_minsk  Price_USA_std  Price_INR_std  Price_USA_scaler
# 0        0.222222       0.126108      -0.453108          0.145617
# 1        0.444444      -0.479212       0.064730         -0.553346
# 2        1.000000       1.336748       1.359325          1.543544
# 3        0.000000      -0.983645      -0.970947         -1.135815

# %%
data['Price_INR_scaler'] = scaler.fit_transform(data[['Price_INR']])
data
# Out:
#    Price_USA  Price_INR  Price_USA_minmax  Price_INR_minmax  Pice_USA_minsk  \
# 0         80       5000          0.478261          0.222222        0.478261
# 1         50       7000          0.217391          0.444444        0.217391
# 2        140      12000          1.000000          1.000000        1.000000
# 3         25       3000          0.000000          0.000000        0.000000
#
#    Pice_INR_minsk  Price_USA_std  Price_INR_std  Price_USA_scaler  \
# 0        0.222222       0.126108      -0.453108          0.145617
# 1        0.444444      -0.479212       0.064730         -0.553346
# 2        1.000000       1.336748       1.359325          1.543544
# 3        0.000000      -0.983645      -0.970947         -1.135815
#
#    Price_INR_scaler
# 0         -0.523205
# 1          0.074744
# 2          1.569614
# 3         -1.121153

# %%
from sklearn.preprocessing import RobustScaler

# %%
robust = RobustScaler()

# %%
data['Price_USA_robust'] = robust.fit_transform(data[['Price_USA']])
data['Price_USA_robust']
data['Price_INR_robust'] = robust.fit_transform(data[['Price_INR']])
data['Price_USA_robust']
data
# Out:
#    Price_USA  Price_INR  Price_USA_minmax  Price_INR_minmax  Pice_USA_minsk  \
# 0         80       5000          0.478261          0.222222        0.478261
# 1         50       7000          0.217391          0.444444        0.217391
# 2        140      12000          1.000000          1.000000        1.000000
# 3         25       3000          0.000000          0.000000        0.000000
#
#    Pice_INR_minsk  Price_USA_std  Price_INR_std  Price_USA_scaler  \
# 0        0.222222       0.126108      -0.453108          0.145617
# 1        0.444444      -0.479212       0.064730         -0.553346
# 2        1.000000       1.336748       1.359325          1.543544
# 3        0.000000      -0.983645      -0.970947         -1.135815
#
#    Price_INR_scaler  Price_USA_robust  Price_INR_robust
# 0         -0.523205          0.292683         -0.266667
# 1          0.074744         -0.292683          0.266667
# 2          1.569614          1.463415          1.600000
# 3         -1.121153         -0.780488         -0.800000

# %%
# !pip install ucimlrepo
# Out:
# Requirement already satisfied: ucimlrepo in C:\Users\chinn\ml_workshop_env\Lib\site-packages (0.0.7)
# Requirement already satisfied: pandas>=1.0.0 in C:\Users\chinn\ml_workshop_env\Lib\site-packages (from ucimlrepo) (3.0.5)
# Requirement already satisfied: certifi>=2020.12.5 in C:\Users\chinn\ml_workshop_env\Lib\site-packages (from ucimlrepo) (2026.7.22)
# Requirement already satisfied: numpy>=1.26.0 in C:\Users\chinn\ml_workshop_env\Lib\site-packages (from pandas>=1.0.0->ucimlrepo) (2.4.6)
# Requirement already satisfied: python-dateutil>=2.8.2 in C:\Users\chinn\ml_workshop_env\Lib\site-packages (from pandas>=1.0.0->ucimlrepo) (2.9.0.post0)
# Requirement already satisfied: tzdata in C:\Users\chinn\ml_workshop_env\Lib\site-packages (from pandas>=1.0.0->ucimlrepo) (2026.3)
# Requirement already satisfied: six>=1.5 in C:\Users\chinn\ml_workshop_env\Lib\site-packages (from python-dateutil>=2.8.2->pandas>=1.0.0->ucimlrepo) (1.17.0)

# %%
# !pip install seaborn
# Out:
# Requirement already satisfied: seaborn in C:\Users\chinn\ml_workshop_env\Lib\site-packages (0.13.2)
# Requirement already satisfied: numpy!=1.24.0,>=1.20 in C:\Users\chinn\ml_workshop_env\Lib\site-packages (from seaborn) (2.4.6)
# Requirement already satisfied: pandas>=1.2 in C:\Users\chinn\ml_workshop_env\Lib\site-packages (from seaborn) (3.0.5)
# Requirement already satisfied: matplotlib!=3.6.1,>=3.4 in C:\Users\chinn\ml_workshop_env\Lib\site-packages (from seaborn) (3.11.1)
# Requirement already satisfied: contourpy>=1.0.1 in C:\Users\chinn\ml_workshop_env\Lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in C:\Users\chinn\ml_workshop_env\Lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (0.12.1)
# Requirement already satisfied: fonttools>=4.28.2 in C:\Users\chinn\ml_workshop_env\Lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (4.63.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in C:\Users\chinn\ml_workshop_env\Lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (1.5.0)
# Requirement already satisfied: packaging>=20.0 in C:\Users\chinn\ml_workshop_env\Lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (26.3)
# Requirement already satisfied: pillow>=9 in C:\Users\chinn\ml_workshop_env\Lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (12.3.0)
# Requirement already satisfied: pyparsing>=3 in C:\Users\chinn\ml_workshop_env\Lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (3.3.2)
# Requirement already satisfied: python-dateutil>=2.7 in C:\Users\chinn\ml_workshop_env\Lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (2.9.0.post0)
# Requirement already satisfied: tzdata in C:\Users\chinn\ml_workshop_env\Lib\site-packages (from pandas>=1.2->seaborn) (2026.3)
# Requirement already satisfied: six>=1.5 in C:\Users\chinn\ml_workshop_env\Lib\site-packages (from python-dateutil>=2.7->matplotlib!=3.6.1,>=3.4->seaborn) (1.17.0)

# %%
#STEP-01:Import the Libraries

import numpy as np                                                                   # Import NumPy for numerical calculations
import pandas as pd                                                                  # Import Pandas for data handling
import matplotlib.pyplot as plt                                                      # Import Matplotlib for plotting graphs
import seaborn as sns                                                                # Import Seaborn for better visualizations
#-------------------------------------------------------------------------------------------------------------------
from ucimlrepo import fetch_ucirepo                                                  # Import dataset from UCI ML Repository                                                         
from sklearn.linear_model import LinearRegression                                    # Import Linear Regression model
from sklearn.impute import SimpleImputer                                             # Import tool to fill missing values
from sklearn.pipeline import Pipeline                                                # Import Pipeline to combine preprocessing and model steps
from sklearn.compose import ColumnTransformer                                        # Import transformer for preprocessing column
from sklearn.model_selection import train_test_split, GridSearchCV                   # Import data splitting and hyperparameter tuning
from sklearn.preprocessing import OneHotEncoder, PolynomialFeatures                  # Import encoding and polynomial feature tools
from sklearn.metrics import mean_absolute_error, mean_squared_error, r2_score        # Import model evaluation metrics
sns.set_style(style = 'whitegrid')                                                   #To Set the background colour of Graph

# %%
#STEP-02: Loading And Cleaning the Data (autompg dataset)
data = fetch_ucirepo(id = 9)
data
x = data.data.features.copy()  #it returs all nummerical features
y = data.data.targets['mpg']
x
# Out:
#      displacement  cylinders  horsepower  weight  acceleration  model_year  \
# 0           307.0          8       130.0    3504          12.0          70
# 1           350.0          8       165.0    3693          11.5          70
# 2           318.0          8       150.0    3436          11.0          70
# 3           304.0          8       150.0    3433          12.0          70
# 4           302.0          8       140.0    3449          10.5          70
# ..            ...        ...         ...     ...           ...         ...
# 393         140.0          4        86.0    2790          15.6          82
# 394          97.0          4        52.0    2130          24.6          82
# 395         135.0          4        84.0    2295          11.6          82
# 396         120.0          4        79.0    2625          18.6          82
# 397         119.0          4        82.0    2720          19.4          82
#
#      origin
# 0         1
# 1         1
# 2         1
# 3         1
# 4         1
# ..      ...
# 393       1
# 394       2
# 395       1
# 396       1
# 397       1
#
# [398 rows x 7 columns]

# %%
x.describe()
x.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 398 entries, 0 to 397
# Data columns (total 7 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   displacement  398 non-null    float64
#  1   cylinders     398 non-null    int64
#  2   horsepower    392 non-null    float64
#  3   weight        398 non-null    int64
#  4   acceleration  398 non-null    float64
#  5   model_year    398 non-null    int64
#  6   origin        398 non-null    int64
# dtypes: float64(3), int64(4)
# memory usage: 21.9 KB

# %%
x['origin'].unique();
x['horsepower'].unique()
# Out:
# array([130., 165., 150., 140., 198., 220., 215., 225., 190., 170., 160.,
#         95.,  97.,  85.,  88.,  46.,  87.,  90., 113., 200., 210., 193.,
#         nan, 100., 105., 175., 153., 180., 110.,  72.,  86.,  70.,  76.,
#         65.,  69.,  60.,  80.,  54., 208., 155., 112.,  92., 145., 137.,
#        158., 167.,  94., 107., 230.,  49.,  75.,  91., 122.,  67.,  83.,
#         78.,  52.,  61.,  93., 148., 129.,  96.,  71.,  98., 115.,  53.,
#         81.,  79., 120., 152., 102., 108.,  68.,  58., 149.,  89.,  63.,
#         48.,  66., 139., 103., 125., 133., 138., 135., 142.,  77.,  62.,
#        132.,  84.,  64.,  74., 116.,  82.])

# %%
#first we will transform the horse power and origin coloumns
x['horsepower'] = pd.to_numeric(x['horsepower'],errors = 'coerce')
x['origin'] = x['origin'].astype(str)

# %%
x.info();
numerical_features = ['cylinders','displacement','horsepower','weight',
                      'acceleration','model_year']
categorical_features = ['origin']
x = x[numerical_features+categorical_features]
x.info()
#x.isnull().sum()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 398 entries, 0 to 397
# Data columns (total 7 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   displacement  398 non-null    float64
#  1   cylinders     398 non-null    int64
#  2   horsepower    392 non-null    float64
#  3   weight        398 non-null    int64
#  4   acceleration  398 non-null    float64
#  5   model_year    398 non-null    int64
#  6   origin        398 non-null    str
# dtypes: float64(3), int64(3), str(1)
# memory usage: 21.9 KB
# <class 'pandas.DataFrame'>
# RangeIndex: 398 entries, 0 to 397
# Data columns (total 7 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   cylinders     398 non-null    int64
#  1   displacement  398 non-null    float64
#  2   horsepower    392 non-null    float64
#  3   weight        398 non-null    int64
#  4   acceleration  398 non-null    float64
#  5   model_year    398 non-null    int64
#  6   origin        398 non-null    str
# dtypes: float64(3), int64(3), str(1)
# memory usage: 21.9 KB

# %%
x.shape
# Out:
# (398, 7)

# %%
#Step-03:Quick Exploratory Data Analysis
df = x.copy()
df['mpg'] = y
#here we are mapping

# %%
#we are gonna use sunplots() concept to divide plot into multiple plots
fig,axes = plt.subplots(1,3,figsize = (16,4))
#plot graphs as per axes
sns.histplot(df['mpg'],kde = False,ax = axes[0],color = 'black')
axes[0].set_title("MPG Disribution")
sns.scatterplot(x = df['weight'],y = df['mpg'],ax = axes[1],color = 'red')
axes[1].set_title("Weight VS MPG Distribution")
sns.scatterplot(x = df['horsepower'],y = df['mpg'],ax = axes[2],color = 'blue')
axes[2].set_title("HorsePower VS MPG Distribution")
# Out:
# Text(0.5, 1.0, 'HorsePower VS MPG Distribution')

# %%
plt.figure(figsize=(16,4))
sns.heatmap(df.select_dtypes(include=np.number).corr(),
            annot=True,
            cmap='coolwarm',
            center=0)
plt.title("CORRELATION MATRIX")
plt.tight_layout()
plt.show()

# %%
#print(x) , print(y)
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.2,random_state=42)
print("\nTrain Test Split")
print("TRAINING DATA : ",len(x_train))
print("TESTING DATA : ",len(x_test))
print(x_train)
# Out:
# Train Test Split
# TRAINING DATA :  318
# TESTING DATA :  80
#      cylinders  displacement  horsepower  weight  acceleration  model_year  \
# 3            8         304.0       150.0    3433          12.0          70
# 18           4          97.0        88.0    2130          14.5          70
# 376          4          91.0        68.0    2025          18.2          82
# 248          4          91.0        60.0    1800          16.4          78
# 177          4         115.0        95.0    2694          15.0          75
# ..         ...           ...         ...     ...           ...         ...
# 71           3          70.0        97.0    2330          13.5          72
# 106          8         350.0       180.0    4499          12.5          73
# 270          4         134.0        95.0    2515          14.8          78
# 348          4          89.0        62.0    2050          17.3          81
# 102          4          97.0        46.0    1950          21.0          73
#
#     origin
# 3        1
# 18       3
# 376      3
# 248      3
# 177      2
# ..     ...
# 71       3
# 106      1
# 270      3
# 348      3
# 102      2
#
# [318 rows x 7 columns]

# %%
def evaluate(model_name,actual,predicted):
    """This function returns MAE,MSE,RSME,R2-Score"""
    mse=mean_squared_error(actual,predicted)
    return {'Mode Name': model_name,
            'MAE' : mean_absolute_error,
            'MSE' : mse,
            'RSME': np.sqrt(mse),
            'R2_SCORE' : r2_score(actual,predicted)}
results=[]

# %%
base_line_predictions = np.full(len(y_test),y_train.mean())
#base_line_predictions

#in above case we are keeping a baseline predictions
results.append(evaluate("Mean Baseline",y_test,base_line_predictions))
results
# Out:
# [{'Mode Name': 'Mean Baseline',
#   'MAE': <function sklearn.metrics._regression.mean_absolute_error(y_true, y_pred, *, sample_weight=None, multioutput='uniform_average')>,
#   'MSE': 53.98329798069697,
#   'RSME': np.float64(7.347332711991268),
#   'R2_SCORE': -0.00403326341807686}]

# %%
simple_model = LinearRegression()
#we fit the data to the model
simple_model.fit(x_train[['cylinders']],y_train)
simple_model_predictions = simple_model.predict(x_test[['cylinders']])
print(simple_model_predictions)
results.append(evaluate("Simple Linear Regression:Cylinders",y_test,
                        simple_model_predictions))
print(len(results))
print(results)
# Out:
# [28.79679762 28.79679762 21.54413106 14.2914645  14.2914645  28.79679762
#  28.79679762 14.2914645  14.2914645  21.54413106 14.2914645  28.79679762
#  28.79679762 14.2914645  28.79679762 14.2914645  28.79679762 21.54413106
#  14.2914645  28.79679762 28.79679762 21.54413106 21.54413106 28.79679762
#  14.2914645  28.79679762 28.79679762 28.79679762 21.54413106 14.2914645
#  28.79679762 28.79679762 14.2914645  28.79679762 28.79679762 14.2914645
#  21.54413106 14.2914645  14.2914645  28.79679762 21.54413106 28.79679762
#  28.79679762 14.2914645  28.79679762 28.79679762 28.79679762 28.79679762
#  28.79679762 28.79679762 28.79679762 28.79679762 28.79679762 14.2914645
#  21.54413106 14.2914645  14.2914645  28.79679762 28.79679762 21.54413106
#  14.2914645  28.79679762 28.79679762 28.79679762 21.54413106 28.79679762
#  28.79679762 28.79679762 28.79679762 14.2914645  28.79679762 14.2914645
#  14.2914645  21.54413106 21.54413106 14.2914645  21.54413106 28.79679762
#  28.79679762 14.2914645 ]
# 2
# [{'Mode Name': 'Mean Baseline', 'MAE': <function mean_absolute_error at 0x000001123A5FD760>, 'MSE': 53.98329798069697, 'RSME': np.float64(7.347332711991268), 'R2_SCORE': -0.00403326341807686}, {'Mode Name': 'Simple Linear Regression:Cylinders', 'MAE': <function mean_absolute_error at 0x000001123A5FD760>, 'MSE': 19.664864157034096, 'RSME': np.float64(4.434508333179012), 'R2_SCORE': 0.6342539549673287}]

# %%
results
# Out:
# [{'Mode Name': 'Mean Baseline',
#   'MAE': <function sklearn.metrics._regression.mean_absolute_error(y_true, y_pred, *, sample_weight=None, multioutput='uniform_average')>,
#   'MSE': 53.98329798069697,
#   'RSME': np.float64(7.347332711991268),
#   'R2_SCORE': -0.00403326341807686},
#  {'Mode Name': 'Simple Linear Regression:Cylinders',
#   'MAE': <function sklearn.metrics._regression.mean_absolute_error(y_true, y_pred, *, sample_weight=None, multioutput='uniform_average')>,
#   'MSE': 19.664864157034096,
#   'RSME': np.float64(4.434508333179012),
#   'R2_SCORE': 0.6342539549673287}]

# %%
#We will Check intercept value
print(f'Simple Linear Regression Equation')
print(f"Predicted MPG = {simple_model.intercept_}+({simple_model.coef_[0]})*weight")
# Out:
# Simple Linear Regression Equation
# Predicted MPG = 43.30213072996193+(-3.626333278591717)*weight

# %%
simple_model = LinearRegression()
#we fit the data to the model
simple_model.fit(x_train[['displacement']],y_train)
simple_model_predictions_displacement = simple_model.predict(x_test[['displacement']])
print(simple_model_predictions)
results.append(evaluate("Simple Linear Regression:Cylinders",y_test,
                        simple_model_predictions_displacement))
print(len(results))
print(results)
# Out:
# [28.79679762 28.79679762 21.54413106 14.2914645  14.2914645  28.79679762
#  28.79679762 14.2914645  14.2914645  21.54413106 14.2914645  28.79679762
#  28.79679762 14.2914645  28.79679762 14.2914645  28.79679762 21.54413106
#  14.2914645  28.79679762 28.79679762 21.54413106 21.54413106 28.79679762
#  14.2914645  28.79679762 28.79679762 28.79679762 21.54413106 14.2914645
#  28.79679762 28.79679762 14.2914645  28.79679762 28.79679762 14.2914645
#  21.54413106 14.2914645  14.2914645  28.79679762 21.54413106 28.79679762
#  28.79679762 14.2914645  28.79679762 28.79679762 28.79679762 28.79679762
#  28.79679762 28.79679762 28.79679762 28.79679762 28.79679762 14.2914645
#  21.54413106 14.2914645  14.2914645  28.79679762 28.79679762 21.54413106
#  14.2914645  28.79679762 28.79679762 28.79679762 21.54413106 28.79679762
#  28.79679762 28.79679762 28.79679762 14.2914645  28.79679762 14.2914645
#  14.2914645  21.54413106 21.54413106 14.2914645  21.54413106 28.79679762
#  28.79679762 14.2914645 ]
# 3
# [{'Mode Name': 'Mean Baseline', 'MAE': <function mean_absolute_error at 0x000001123A5FD760>, 'MSE': 53.98329798069697, 'RSME': np.float64(7.347332711991268), 'R2_SCORE': -0.00403326341807686}, {'Mode Name': 'Simple Linear Regression:Cylinders', 'MAE': <function mean_absolute_error at 0x000001123A5FD760>, 'MSE': 19.664864157034096, 'RSME': np.float64(4.434508333179012), 'R2_SCORE': 0.6342539549673287}, {'Mode Name': 'Simple Linear Regression:Cylinders', 'MAE': <function mean_absolute_error at 0x000001123A5FD760>, 'MSE': 18.102543998358946, 'RSME': np.float64(4.254708450453326), 'R2_SCORE': 0.6633114869465596}]

# %%
x.isnull().sum()
# Out:
# cylinders       0
# displacement    0
# horsepower      6
# weight          0
# acceleration    0
# model_year      0
# origin          0
# dtype: int64

# %%
preprocessor = ColumnTransformer(transformers=[
    ("numbers",SimpleImputer(strategy="median"),
     numerical_features),
    ("category",Pipeline(steps = [("imputer",SimpleImputer(strategy="most_frequent")),
                                  ("encoder",OneHotEncoder(handle_unknown="ignore",drop = "first"),
                                   )]),
categorical_features),
]
)
preprocessor
# Out:
# ColumnTransformer(transformers=[('numbers', SimpleImputer(strategy='median'),
#                                  ['cylinders', 'displacement', 'horsepower',
#                                   'weight', 'acceleration', 'model_year']),
#                                 ('category',
#                                  Pipeline(steps=[('imputer',
#                                                   SimpleImputer(strategy='most_frequent')),
#                                                  ('encoder',
#                                                   OneHotEncoder(drop='first',
#                                                                 handle_unknown='ignore'))]),
#                                  ['origin'])])

# %%
multiple_model = Pipeline(
    steps = [("prepare",preprocessor),
        ("model",LinearRegression())]
)
multiple_model.fit(x_train,y_train)
# Out:
# Pipeline(steps=[('prepare',
#                  ColumnTransformer(transformers=[('numbers',
#                                                   SimpleImputer(strategy='median'),
#                                                   ['cylinders', 'displacement',
#                                                    'horsepower', 'weight',
#                                                    'acceleration',
#                                                    'model_year']),
#                                                  ('category',
#                                                   Pipeline(steps=[('imputer',
#                                                                    SimpleImputer(strategy='most_frequent')),
#                                                                   ('encoder',
#                                                                    OneHotEncoder(drop='first',
#                                                                                  handle_unknown='ignore'))]),
#                                                   ['origin'])])),
#                 ('model', LinearRegression())])

# %%
multiple_predictions = multiple_model.predict(x_test)
results.append(evaluate("Multiple Regression",y_test,multiple_predictions))
results
# Out:
# [{'Mode Name': 'Mean Baseline',
#   'MAE': <function sklearn.metrics._regression.mean_absolute_error(y_true, y_pred, *, sample_weight=None, multioutput='uniform_average')>,
#   'MSE': 53.98329798069697,
#   'RSME': np.float64(7.347332711991268),
#   'R2_SCORE': -0.00403326341807686},
#  {'Mode Name': 'Simple Linear Regression:Cylinders',
#   'MAE': <function sklearn.metrics._regression.mean_absolute_error(y_true, y_pred, *, sample_weight=None, multioutput='uniform_average')>,
#   'MSE': 19.664864157034096,
#   'RSME': np.float64(4.434508333179012),
#   'R2_SCORE': 0.6342539549673287},
#  {'Mode Name': 'Simple Linear Regression:Cylinders',
#   'MAE': <function sklearn.metrics._regression.mean_absolute_error(y_true, y_pred, *, sample_weight=None, multioutput='uniform_average')>,
#   'MSE': 18.102543998358946,
#   'RSME': np.float64(4.254708450453326),
#   'R2_SCORE': 0.6633114869465596},
#  {'Mode Name': 'Multiple Regression',
#   'MAE': <function sklearn.metrics._regression.mean_absolute_error(y_true, y_pred, *, sample_weight=None, multioutput='uniform_average')>,
#   'MSE': 8.338667873348687,
#   'RSME': np.float64(2.8876751675610413),
#   'R2_SCORE': 0.8449094399450832}]

# %%
#it forms curvlinear relationship
from sklearn.pipeline import Pipeline
from sklearn.preprocessing import PolynomialFeatures
polynomial_model = Pipeline(
    steps = [("imputer",SimpleImputer(strategy="median")),
    ("polynomial",PolynomialFeatures(include_bias=False)),
    ("model",LinearRegression())])
#polynomial_model
#Selecting the Polynomial Degree
degree_search = GridSearchCV(
    polynomial_model,
    param_grid = {'polynomial__degree':[1,2,3,4,5]},
    scoring = "neg_mean_squared_error",
    cv=5)

# %%
degree_search.fit(x_train[['horsepower']],y_train)
polynomial_predictions = degree_search.predict(x_test[['horsepower']])
results.append(evaluate("Polynomial: Horse Power",y_test,
                        
                        
                        
                        
                        
                        
                        
                        polynomial_predictions))
results
# Out:
# [{'Mode Name': 'Mean Baseline',
#   'MAE': <function sklearn.metrics._regression.mean_absolute_error(y_true, y_pred, *, sample_weight=None, multioutput='uniform_average')>,
#   'MSE': 53.98329798069697,
#   'RSME': np.float64(7.347332711991268),
#   'R2_SCORE': -0.00403326341807686},
#  {'Mode Name': 'Simple Linear Regression:Cylinders',
#   'MAE': <function sklearn.metrics._regression.mean_absolute_error(y_true, y_pred, *, sample_weight=None, multioutput='uniform_average')>,
#   'MSE': 19.664864157034096,
#   'RSME': np.float64(4.434508333179012),
#   'R2_SCORE': 0.6342539549673287},
#  {'Mode Name': 'Simple Linear Regression:Cylinders',
#   'MAE': <function sklearn.metrics._regression.mean_absolute_error(y_true, y_pred, *, sample_weight=None, multioutput='uniform_average')>,
#   'MSE': 18.102543998358946,
#   'RSME': np.float64(4.254708450453326),
#   'R2_SCORE': 0.6633114869465596},
#  {'Mode Name': 'Multiple Regression',
#   'MAE': <function sklearn.metrics._regression.mean_absolute_error(y_true, y_pred, *, sample_weight=None, multioutput='uniform_average')>,
#   'MSE': 8.338667873348687,
#   'RSME': np.float64(2.8876751675610413),
#   'R2_SCORE': 0.8449094399450832},
#  {'Mode Name': 'Polynomial: Horse Power',
#   'MAE': <function sklearn.metrics._regression.mean_absolute_error(y_true, y_pred, *, sample_weight=None, multioutput='uniform_average')>,
#   'MSE': 13.978713313447923,
#   'RSME': np.float64(3.7388117515392403),
#   'R2_SCORE': 0.7400104537609868}]

# %%
#Finding the Best Degree
best_degree = degree_search.best_params_['polynomial__degree']
cv_rsme = np.sqrt(-degree_search.best_score_)
print(best_degree)
print(cv_rsme)
# Out:
# 2
# 4.620314169891041

# %%
results = pd.DataFrame(results).sort_values("RMSE")
results
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[79], line 1
# ----> 1 results = pd.DataFrame(results).sort_values("RMSE")
#       2 results
#
# File ~\ml_workshop_env\Lib\site-packages\pandas\core\frame.py:8361, in DataFrame.sort_values(self, by, axis, ascending, inplace, kind, na_position, ignore_index, key)
#    8357             )
#    8358         elif by:
#    8359             # len(by) == 1
#    8360
# -> 8361             k = self._get_label_or_level_values(by[0], axis=axis)
#    8362
#    8363             # need to rewrap column in Series to apply key function
#    8364             if key is not None:
#
# File ~\ml_workshop_env\Lib\site-packages\pandas\core\generic.py:1764, in NDFrame._get_label_or_level_values(self, key, axis)
#    1760             values = self.xs(key, axis=first_other_axes)._values
#    1761         elif self._is_level_reference(key, axis=axis):
#    1762             values = self.axes[axis].get_level_values(key)._values
#    1763         else:
# -> 1764             raise KeyError(key)
#    1765
#    1766         # Check for duplicates
#    1767         if values.ndim > 1:
#
# KeyError: 'RMSE'
